# %%
from dotenv import load_dotenv
load_dotenv()
 
# autoreload extension, always reload module when running cells
# %load_ext autoreload 
# %autoreload 2

# %%
# Add root folder as module source also
import sys
import os
sys.path.append(os.path.abspath(".."))
